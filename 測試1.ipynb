# %% [markdown]
# <a href="https://colab.research.google.com/github/11561616/Colab/blob/main/%E6%B8%AC%E8%A9%A61.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://tabelog.com/tw/tokyo/rstLst/?SrtT=rt"
response = requests.get(url)
html = BeautifulSoup(response.text, "html.parser")
# 區塊.find/find_all(區塊html名字, 篩選條件class/id)
rest = html.find_all("li", {"class":"list-rst"})
for r in rest:  # r: 一個li區塊
    en = r.find("a", {"class":"list-rst__name-main"})  # 英文名稱
    ja = r.find("small", {"class":"list-rst__name-ja"})  # 日文名稱
    rtype = r.find("li", {"class":"list-rst__catg"})  # 菜的類別
    rating = r.find("b", {"class":"c-rating__val"})  # 評分
    price = r.find_all("span", {"class":"c-rating__val"})  # 價格
    print(en.text)
    print(ja.text)
    print(rtype.text)
    print(rating.text)
    print("午餐:", price[0].text)  # 午餐價格
    print("晚餐:", price[1].text)  # 晚餐價格
    print(en["href"])  # 網址
    print("-" * 30)  # 分隔符號
# Out:
# Sugita
# 日本橋蛎殻町 すぎた
# 壽司
# 4.71
# 午餐: ￥40,000～￥49,999
# 晚餐: ￥40,000～￥49,999
# https://tabelog.com/tw/tokyo/A1302/A130204/13018162/
# ------------------------------
# Amamoto
# 東麻布 天本
# 壽司
# 4.64
# 午餐: ￥50,000～￥59,999
# 晚餐: -
# https://tabelog.com/tw/tokyo/A1314/A131401/13196420/
# ------------------------------
# Hoshino
# 新ばし 星野
# 日本料理
# 4.63
# 午餐: ￥40,000～￥49,999
# 晚餐: -
# https://tabelog.com/tw/tokyo/A1314/A131401/13136847/
# ------------------------------
# Aca 1°
# アカ
# 西班牙料理
# 4.62
# 午餐: ￥50,000～￥59,999
# 晚餐: ￥40,000～￥49,999
# https://tabelog.com/tw/tokyo/A1302/A130202/13249117/
# ------------------------------
# Matsukawa
# 松川
# 日本料理
# 4.61
# 午餐: ￥60,000～￥79,999
# 晚餐: ￥60,000～￥79,999
# https://tabelog.com/tw/tokyo/A1307/A130701/13124391/
# ------------------------------
# Saito
# 鮨 さいとう
# 壽司
# 4.59
# 午餐: ￥30,000～￥39,999
# 晚餐: ￥30,000～￥39,999
# https://tabelog.com/tw/tokyo/A1308/A130802/13015251/
# ------------------------------
# PELLEGRINO
# ペレグリーノ
# 義式
# 4.59
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://tabelog.com/tw/tokyo/rstLst/?SrtT=rt"
response = requests.get(url)
html = BeautifulSoup(response.text, "html.parser")
# 區塊.find/find_all(區塊html名字, 篩選條件class/id)
rest = html.find_all("li", {"class":"list-rst"})
for r in rest:  # r: 一個li區塊
    en = r.find("a", {"class":"list-rst__name-main"})  # 英文名稱
    
    print(en)
    
    print("-" * 30)  # 分隔符號
# Out:
# <a class="list-rst__name-main js-detail-anchor" href="https://tabelog.com/tw/tokyo/A1302/A130204/13018162/" target="_blank">Sugita</a>
# ------------------------------
# <a class="list-rst__name-main js-detail-anchor" href="https://tabelog.com/tw/tokyo/A1314/A131401/13196420/" target="_blank">Amamoto</a>
# ------------------------------
# <a class="list-rst__name-main js-detail-anchor" href="https://tabelog.com/tw/tokyo/A1302/A130202/13249117/" target="_blank">Aca 1°</a>
# ------------------------------
# <a class="list-rst__name-main js-detail-anchor" href="https://tabelog.com/tw/tokyo/A1314/A131401/13136847/" target="_blank">Hoshino</a>
# ------------------------------
# <a class="list-rst__name-main js-detail-anchor" href="https://tabelog.com/tw/tokyo/A1307/A130701/13124391/" target="_blank">Matsukawa</a>
# ------------------------------
# <a class="list-rst__name-main js-detail-anchor" href="https://tabelog.com/tw/tokyo/A1308/A130802/13015251/" target="_blank">Saito</a>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://ifoodie.tw/explore/%E5%B1%8F%E6%9D%B1%E7%B8%A3/list"
response = requests.get(url)
html = BeautifulSoup(response.text, "html.parser")
# 區塊.find/find_all(區塊html名字, 篩選條件class/id)
rest = html.find_all("div", {"class":"jsx-1156793088 info-rows"})
for r in rest:  # r: 一個li區塊
    na = r.find("a", {"class":"jsx-1156793088 title-text"})   # 名稱
    rating = r.find("div", {"class":"jsx-2373119553 text"})   # 評分
    time = r.find("div", {"class":"jsx-1156793088 info"})    # 營業時間
    ad = r.find("div", {"class":"jsx-1156793088 address-row"})  # 地址
    ty = r.find("a", {"class":"jsx-1156793088 category"})   # 類型
    phone = r.find("a", {"class":"jsx-2591663717 detail"})
    money = r.find("div", {"class":"jsx-1156793088 avg-price"})
    print(na.text)
    print("評分:",rating.text)
    print(time.text)
    print(ad.text)
    #print(phone.text)
    #print(money.text)
    print(ty.text)
    print("https://ifoodie.tw/",na["href"])  # 網址
    print("-" * 50)  # 分隔符號
# Out:
# CACAO FARM FORMOSA 福爾摩莎可可農場
# 評分: 4.6
# 今日營業: 11:00-18:00
# 屏東縣內埔鄉大同路三段榮和巷80號
# 附近餐廳
# https://ifoodie.tw/ /restaurant/606728757cc7fc5b0c90e833-CACAO-FARM-FORMOSA-%E7%A6%8F
# --------------------------------------------------
# 海龜咖啡 SeaTurtle Cafe
# 評分: 4.6
# 今日營業: 13:00-18:00
# 屏東縣恆春鎮萬裏路18之3號
# 附近餐廳
# https://ifoodie.tw/ /restaurant/5d4d4a3522613922b032845f-%E6%B5%B7%E9%BE%9C%E5%92%96%E5%95%A1-SeaTurtle-Cafe
# --------------------------------------------------
# 老夫子甜不辣
# 評分: 3.6
# 今日休息
# 屏東縣屏東市林森路98之1號
# 附近餐廳
# https://ifoodie.tw/ /restaurant/5587b8bbc03a100eb02ba4d4-%E8%80%81%E5%A4%AB%E5%AD%90%E7%94%9C%E4%B8%8D%E8%BE%A3
# --------------------------------------------------
# 波波俱樂部
# 評分: 4.9
# 尚無營業時間資訊
# 屏東縣恆春鎮環城北路52號
# 附近餐廳
# https://ifoodie.tw/ /restaurant/63d9171f01ba3353ea9c8552-%E6%B3%A2%E6%B3%A2%E4%BF%B1%E6%A8%82%E9%83%A8
# --------------------------------------------------
# 阿興生魚片
# 評分: 4.7
# 今日營業: 11:00-19:30
# 屏東縣恆春鎮大光路8之11號
# 附近餐廳
# ...
